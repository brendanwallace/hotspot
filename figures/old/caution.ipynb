# %%
import numpy as np
import json
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import alpha

DATA_LOCATION = '/Users/brendan/Documents/projects/risky_sir/go/data/'
FILE = DATA_LOCATION + "caution.json"
with open(FILE) as file:
    data = json.load(file)


EXTINCTION_CUTOFF = 50
#TRIALS = 10

linestyles = ['-', '--', ':']
colors = ["blue", "magenta", "red", "green"]

# %%
for i in range(2):
    Y = data[i]['DifEqResults']['Is']
    total = data[i]['DifEqResults']['FinalR']
    plt.plot(Y, label=f'{i} {total}')
plt.plot(data[2]['DifEqResults']['Is'], '--', label=data[2]['DifEqResults']['FinalR'])
plt.legend()

# %%
for i in range(0, 3):
    Y = data[i]['DifEqResults']['Rts']
    plt.plot(Y, '--', label=i)
plt.legend()
